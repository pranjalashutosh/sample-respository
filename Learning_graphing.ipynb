# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.arange(0, 5*np.pi,0.1)
y=np.sin(x)

plt.plot(x,y)
plt.xlabel('x - axis')
plt.ylabel('y - axis')
plt.show()
#time=np.arange(0,10,0.1)
#y=np.sin(np.pi*time)
#plt.plot(time,y)

# %%
T = 1  # period (seconds)
fs = 1000  # sampling frequency (Hz)
#time = np.linspace( 0,T, T*fs, endpoint=False)
#print(time)
time = np.arange(0, 5*np.pi,0.1)
array=np.arange(1,5000,2)
#print(array)
frequency_sine = 5  # frequency (Hz)
sine_wave = np.sin(2 * np.pi * frequency_sine * time)
#plt.plot(sine_wave)
f=3/2;
for odd in array:
        f = f+(6/(odd*np.pi))*(np.sin(odd*time))# Fourier Series
plt.plot(f)

# %%
z1 = complex(1, 2)
t=np.arange(0,10,1)
z2=complex(2,3)
print(z1+z2)
z3=complex(z1.real,z2.imag)
print(z3)
# Out:
# (3+5j)
# (1+3j)

# %%
import math
def exp(x):
    return sum([
        x**n/math.factorial(n)
        for n in range(0,100)
    ])
exp(1)
# Out:
# 2.718281828459045

# %%
# %matplotlib inline

def generate_figure(figsize=(10, 10), xlim=[0, 1], ylim=[0, 1]):
    
    plt.figure(figsize=figsize)
    plt.grid()
    plt.xlim(xlim)
    plt.ylim(ylim)
    plt.xlabel(r'$\mathrm{Re}$')
    plt.ylabel(r'$\mathrm{Im}$')

def plot_vector(c, color='k', start=0, linestyle='-'):
 
    return plt.arrow(np.real(start), np.imag(start), np.real(c), np.imag(c),
                     linestyle=linestyle, head_width=0.05, fc=color, ec=color, overhang=0.3,
                     length_includes_head=T)

c = 1.5 + 0.8j

generate_figure(figsize=(5, 3), xlim=[0, 2.5], ylim=[0, 1])
v = plot_vector(c, color='k')

plt.text(1.5, 0.8, '$c$', size='16')
plt.text(0.65, 0.45, '$|c|$', size='16')
plt.text(0.25, 0.05, '$\gamma$', size='16');
# Out:
# <>:25: SyntaxWarning: invalid escape sequence '\g'
# <>:25: SyntaxWarning: invalid escape sequence '\g'
# C:\Users\pranj\AppData\Local\Temp\ipykernel_17520\2778557013.py:25: SyntaxWarning: invalid escape sequence '\g'
#   plt.text(0.25, 0.05, '$\gamma$', size='16');

# %%
arr=complex(np.cos(np.pi),np.sin(np.pi))
print(arr)
print(exp(complex(0,np.pi)))
# Out:
# (-1+1.2246467991473532e-16j)
# (-1.0000000000000002+3.458669144327514e-16j)

# %%
exp(2+3)
# Out:
# 148.4131591025766

# %%
exp(2)*exp(3)
# Out:
# 148.4131591025766

# %%
#this means exp(a+b) = exp(a)*exp(b)
